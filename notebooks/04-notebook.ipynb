# %%
import os

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# Inicializar el modelo Gemini
gemini_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
response = gemini_llm.invoke("Hola, ¿cómo estás?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ¡Hola! Estoy muy bien, gracias por preguntar. Como soy una inteligencia artificial, no tengo sentimientos, pero estoy listo y funcionando perfectamente para ayudarte en lo que necesites.
#
# ¿Y tú, cómo estás?

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

#Historial de mensajes
msg_1 = SystemMessage(content="You are a helpful assistant that talks in spanish")
msg_2 = HumanMessage(content="Me llamo Juan")
msg_3 = AIMessage(content="Hola Juan, como estas?")
msg_4 = HumanMessage(content="Como me llamo?")
history = [msg_1, msg_2, msg_3, msg_4]
response = gemini_llm.invoke(history)
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Te llamas Juan.

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("gemini-2.5-flash",model_provider="google_genai", temperature=0)
response = llm.invoke(history)
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Te llamas Juan.
